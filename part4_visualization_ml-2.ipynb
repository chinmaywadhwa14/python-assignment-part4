# %%
import pandas as pd
from io import StringIO

# Creating dataset directly (no upload needed)
data = """name,math,science,english,history,pe,attendance_pct,study_hours_per_day,passed
Alice,88,92,76,80,95,92,4.5,1
Bob,42,55,48,50,60,65,1.2,0
Charlie,75,70,80,68,88,85,3.0,1
Diana,95,98,91,89,97,98,6.0,1
Eve,38,42,50,45,55,58,0.8,0
Frank,60,65,72,58,70,78,2.5,1
Grace,55,48,44,52,62,60,1.5,0
Henry,82,79,85,77,90,88,4.0,1
Iris,70,74,68,65,78,80,3.5,1
Jack,30,35,40,28,45,50,0.5,0
Karen,65,60,70,62,75,72,2.8,1
Liam,48,52,44,55,58,62,1.8,0
Mia,91,94,88,92,96,95,5.5,1
Noah,58,62,55,60,68,70,2.0,0
Olivia,78,75,82,70,85,84,3.8,1
"""

df = pd.read_csv(StringIO(data))

# Show first 5 rows
df.head()
# Out:
#       name  math  science  english  history  pe  attendance_pct  \
# 0    Alice    88       92       76       80  95              92
# 1      Bob    42       55       48       50  60              65
# 2  Charlie    75       70       80       68  88              85
# 3    Diana    95       98       91       89  97              98
# 4      Eve    38       42       50       45  55              58
#
#    study_hours_per_day  passed
# 0                  4.5       1
# 1                  1.2       0
# 2                  3.0       1
# 3                  6.0       1
# 4                  0.8       0

# %%
# Displaying the first 5 rows to understand the dataset structure
df.head()
# Out:
#       name  math  science  english  history  pe  attendance_pct  \
# 0    Alice    88       92       76       80  95              92
# 1      Bob    42       55       48       50  60              65
# 2  Charlie    75       70       80       68  88              85
# 3    Diana    95       98       91       89  97              98
# 4      Eve    38       42       50       45  55              58
#
#    study_hours_per_day  passed
# 0                  4.5       1
# 1                  1.2       0
# 2                  3.0       1
# 3                  6.0       1
# 4                  0.8       0

# %%
# Checking number of rows and columns along with data types
print("Shape of dataset:", df.shape)

print("\nData types of each column:\n")
print(df.dtypes)
# Out:
# Shape of dataset: (15, 9)
#
# Data types of each column:
#
# name                    object
# math                     int64
# science                  int64
# english                  int64
# history                  int64
# pe                       int64
# attendance_pct           int64
# study_hours_per_day    float64
# passed                   int64
# dtype: object

# %%
# Getting summary statistics like mean, min, max, std for numerical columns
df.describe()
# Out:
#             math    science    english    history         pe  attendance_pct  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000       15.000000
# mean   65.000000  66.733333  66.200000  63.400000  74.800000       75.800000
# std    20.060622  18.967893  17.773174  16.936014  16.657045       14.722189
# min    30.000000  35.000000  40.000000  28.000000  45.000000       50.000000
# 25%    51.500000  53.500000  49.000000  53.500000  61.000000       63.500000
# 50%    65.000000  65.000000  70.000000  62.000000  75.000000       78.000000
# 75%    80.000000  77.000000  81.000000  73.500000  89.000000       86.500000
# max    95.000000  98.000000  91.000000  92.000000  97.000000       98.000000
#
#        study_hours_per_day     passed
# count            15.000000  15.000000
# mean              2.893333   0.600000
# std               1.658944   0.507093
# min               0.500000   0.000000
# 25%               1.650000   0.000000
# 50%               2.800000   1.000000
# ...

# %%
# Counting how many students passed and failed
df['passed'].value_counts()
# Out:
# passed
# 1    9
# 0    6
# Name: count, dtype: int64

# %%
# Calculating average scores for each subject based on pass/fail

subject_cols = ['math', 'science', 'english', 'history', 'pe']

print("Average scores of students who passed:\n")
print(df[df['passed'] == 1][subject_cols].mean())

print("\nAverage scores of students who failed:\n")
print(df[df['passed'] == 0][subject_cols].mean())
# Out:
# Average scores of students who passed:
#
# math       78.222222
# science    78.555556
# english    79.111111
# history    73.444444
# pe         86.000000
# dtype: float64
#
# Average scores of students who failed:
#
# math       45.166667
# science    49.000000
# english    46.833333
# history    48.333333
# pe         58.000000
# dtype: float64

# %%
# Calculating average scores for each subject based on pass/fail

subject_cols = ['math', 'science', 'english', 'history', 'pe']

print("Average scores of students who passed:\n")
print(df[df['passed'] == 1][subject_cols].mean())

print("\nAverage scores of students who failed:\n")
print(df[df['passed'] == 0][subject_cols].mean())
# Out:
# Average scores of students who passed:
#
# math       78.222222
# science    78.555556
# english    79.111111
# history    73.444444
# pe         86.000000
# dtype: float64
#
# Average scores of students who failed:
#
# math       45.166667
# science    49.000000
# english    46.833333
# history    48.333333
# pe         58.000000
# dtype: float64

# %%
# Finding the student with highest average score

# Creating a new column for average score
df['avg_score'] = df[['math','science','english','history','pe']].mean(axis=1)

# Getting the top student
top_student = df.loc[df['avg_score'].idxmax()]

print("Top performing student:\n")
top_student
# Out:
# Top performing student:
# name                   Diana
# math                      95
# science                   98
# english                   91
# history                   89
# pe                        97
# attendance_pct            98
# study_hours_per_day      6.0
# passed                     1
# avg_score               94.0
# Name: 3, dtype: object

# %% [markdown]
# In this task, I analyzed student performance data using pandas by exploring structure, statistics, and performance differences between passed and failed students.

# %%
# Saving dataset as CSV file for submission

df.to_csv("students.csv", index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
# Creating avg_score column (REQUIRED for Task 2)

subject_cols = ['math', 'science', 'english', 'history', 'pe']
df['avg_score'] = df[subject_cols].mean(axis=1)

# %%
import matplotlib.pyplot as plt

# Average score per subject
avg_scores = df[subject_cols].mean()

plt.figure()
plt.bar(avg_scores.index, avg_scores.values)

plt.title("Average Score per Subject")
plt.xlabel("Subjects")
plt.ylabel("Average Score")

plt.savefig("plot1_bar.png")
plt.show()

# %%
plt.figure()

plt.hist(df['math'], bins=5)

plt.axvline(df['math'].mean(), linestyle='dashed')

plt.title("Distribution of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")

plt.savefig("plot2_hist.png")
plt.show()

# %%
plt.figure()

# Pass students
plt.scatter(df[df['passed'] == 1]['study_hours_per_day'],
            df[df['passed'] == 1]['avg_score'],
            label="Pass")

# Fail students
plt.scatter(df[df['passed'] == 0]['study_hours_per_day'],
            df[df['passed'] == 0]['avg_score'],
            label="Fail")

plt.title("Study Hours vs Average Score")
plt.xlabel("Study Hours per Day")
plt.ylabel("Average Score")
plt.legend()

plt.savefig("plot3_scatter.png")
plt.show()

# %%
plt.figure()

pass_attendance = df[df['passed'] == 1]['attendance_pct']
fail_attendance = df[df['passed'] == 0]['attendance_pct']

plt.boxplot([pass_attendance, fail_attendance],
            labels=["Pass", "Fail"])

plt.title("Attendance Comparison (Pass vs Fail)")
plt.ylabel("Attendance %")

plt.savefig("plot4_box.png")
plt.show()
# Out:
# /tmp/ipykernel_1608/3942961160.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([pass_attendance, fail_attendance],

# %%
plt.figure()

plt.plot(df['name'], df['math'], marker='o', label='Math')
plt.plot(df['name'], df['science'], marker='o', label='Science')

plt.xticks(rotation=45)

plt.title("Math & Science Scores per Student")
plt.xlabel("Student Name")
plt.ylabel("Score")
plt.legend()

plt.savefig("plot5_line.png")
plt.show()
